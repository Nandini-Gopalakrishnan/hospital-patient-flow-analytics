# %%
import pandas as pd

# %%
df=pd.read_excel("doctor_profiles_without_duplicate_column.xlsx")

# %%
d1=df.iloc[0:20000]
d2=df.iloc[20000:40000]
d3=df.iloc[40000:60000]
d4=df.iloc[60000:80000]
d5=df.iloc[80000:100000]
d1.to_csv("d1.csv", index=False)
d2.to_csv("d2.csv", index=False)
d3.to_csv("d3.csv", index=False)
d4.to_csv("d4.csv", index=False)
d5.to_csv("d5.csv", index=False)

# %%
print("shape ",df.shape)
print("columns ", df.columns)
print("head ",df.head())
print("tail ",df.tail())
print("info ",df.info())
# Out:
# shape  (100000, 4)
# columns  Index(['doctor_id', 'specialization', 'experience_years',
#        'performance_rating'],
#       dtype='object')
# head    doctor_id    specialization  experience_years  performance_rating
# 0    D00000  Gastroenterology                 9                1.39
# 1    D00001        Cardiology                36                2.38
# 2    D00002          Oncology                 6                2.11
# 3    D00003  Gastroenterology                24                4.98
# 4    D00004        Pediatrics                26                4.43
# tail        doctor_id    specialization  experience_years  performance_rating
# 99995    D99995  Gastroenterology                 4                4.39
# 99996    D99996       Orthopedics                 4                3.07
# 99997    D99997        Pediatrics                15                4.73
# 99998    D99998        Cardiology                36                2.26
# ...

# %%
df.isnull().sum()
# Out:
# doctor_id             0
# specialization        0
# experience_years      0
# performance_rating    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.select_dtypes(include="object"):
    print(f"{col} unique values:", df[col].unique()[:10])
# Out:
# doctor_id unique values: ['D00000' 'D00001' 'D00002' 'D00003' 'D00004' 'D00005' 'D00006' 'D00007'
#  'D00008' 'D00009']
# specialization unique values: ['Gastroenterology' 'Cardiology' 'Oncology' 'Pediatrics' 'Orthopedics'
#  'Urology' 'Neurology' 'Emergency']

# %%
df.describe()
# Out:
#        experience_years  performance_rating
# count     100000.000000       100000.000000
# mean          20.512210            3.007855
# std           11.537721            1.155295
# min            1.000000            1.000000
# 25%           11.000000            2.000000
# 50%           20.000000            3.010000
# 75%           31.000000            4.000000
# max           40.000000            5.000000

# %%
for col in df.select_dtypes(include="object"):
    print(col, df[col].unique())
# Out:
# doctor_id ['D00000' 'D00001' 'D00002' ... 'D99997' 'D99998' 'D99999']
# specialization ['Gastroenterology' 'Cardiology' 'Oncology' 'Pediatrics' 'Orthopedics'
#  'Urology' 'Neurology' 'Emergency']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   doctor_id           100000 non-null  object
#  1   specialization      100000 non-null  object
#  2   experience_years    100000 non-null  int64
#  3   performance_rating  100000 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
p_df=pd.read_csv("patient_admissions.csv")
p1=p_df.iloc[0:20000]
p2=p_df.iloc[20000:40000]
p3=p_df.iloc[40000:60000]
p4=p_df.iloc[60000:80000]
p5=p_df.iloc[80000:100000]
p1.to_csv("p1.csv", index=False)
p2.to_csv("p2.csv", index=False)
p3.to_csv("p3.csv", index=False)
p4.to_csv("p4.csv", index=False)
p5.to_csv("p5.csv", index=False)

# %%
p_df.duplicated().sum()
# Out:
# 0

# %%
p_df.isnull().sum()
# Out:
# patient_id        0
# admission_date    0
# age               0
# gender            0
# diagnosis         0
# department        0
# discharge_date    0
# dtype: int64

# %%
p_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   patient_id      100000 non-null  object
#  1   admission_date  100000 non-null  object
#  2   age             100000 non-null  int64
#  3   gender          100000 non-null  object
#  4   diagnosis       100000 non-null  object
#  5   department      100000 non-null  object
#  6   discharge_date  100000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
print("columns ", p_df.columns)
# Out:
# columns  Index(['patient_id', 'admission_date', 'age', 'gender', 'diagnosis',
#        'department', 'discharge_date'],
#       dtype='object')

# %%
for col in p_df.select_dtypes(include="object"):
    print(col, p_df[col].unique())
# Out:
# patient_id ['P00000' 'P00001' 'P00002' ... 'P99997' 'P99998' 'P99999']
# admission_date ['17-05-2025' '24-11-2024' '15-12-2023' '18-01-2024' '02-05-2025'
#  '28-12-2024' '18-12-2023' '19-01-2024' '19-11-2023' '22-01-2025'
#  '21-01-2025' '18-06-2025' '29-10-2023' '01-03-2025' '24-05-2025'
#  '04-02-2025' '23-11-2023' '27-06-2024' '15-10-2023' '13-05-2024'
#  '07-12-2024' '03-03-2025' '07-06-2025' '07-01-2025' '05-08-2024'
#  '26-04-2025' '19-08-2023' '23-05-2024' '05-04-2025' '25-04-2024'
#  '09-05-2024' '30-07-2024' '10-12-2023' '08-05-2025' '05-10-2023'
#  '26-11-2023' '04-12-2024' '19-05-2025' '20-11-2024' '14-11-2023'
#  '11-06-2024' '09-04-2024' '15-11-2024' '17-09-2023' '09-12-2024'
#  '04-07-2024' '29-06-2024' '14-07-2024' '17-12-2024' '25-05-2025'
#  '09-07-2024' '23-04-2024' '04-04-2024' '18-05-2024' '31-01-2025'
#  '15-05-2024' '14-06-2024' '04-12-2023' '30-06-2024' '18-05-2025'
#  '16-10-2024' '06-03-2025' '31-08-2024' '28-02-2025' '15-09-2024'
# ...

# %%
t_df=pd.read_csv("treatment_records.csv")
t1=t_df.iloc[0:20000]
t2=t_df.iloc[20000:40000]
t3=t_df.iloc[40000:60000]
t4=t_df.iloc[60000:80000]
t5=t_df.iloc[80000:100000]
t1.to_csv("t1.csv", index=False)
t2.to_csv("t2.csv", index=False)
t3.to_csv("t3.csv", index=False)
t4.to_csv("t4.csv", index=False)
t5.to_csv("t5.csv", index=False)

# %%
t_df.duplicated().sum()
# Out:
# 0

# %%
t_df.isnull().sum()
# Out:
# treatment_id      0
# patient_id        0
# doctor_id         0
# treatment_type    0
# treatment_date    0
# success           0
# cost              0
# dtype: int64

# %%
t_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   treatment_id    100000 non-null  object
#  1   patient_id      100000 non-null  object
#  2   doctor_id       100000 non-null  object
#  3   treatment_type  100000 non-null  object
#  4   treatment_date  100000 non-null  object
#  5   success         100000 non-null  int64
#  6   cost            100000 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 5.3+ MB

# %%
print("columns ", t_df.columns)
# Out:
# columns  Index(['treatment_id', 'patient_id', 'doctor_id', 'treatment_type',
#        'treatment_date', 'success', 'cost'],
#       dtype='object')

# %%
for col in t_df.select_dtypes(include="object"):
    print(col, t_df[col].unique())
# Out:
# treatment_id ['T000000' 'T000001' 'T000002' ... 'T099997' 'T099998' 'T099999']
# patient_id ['P25795' 'P10860' 'P86820' ... 'P63946' 'P18194' 'P29662']
# doctor_id ['D8003' 'D6579' 'D4421' ... 'D3977' 'D2472' 'D4448']
# treatment_type ['Surgery' 'Medication' 'Consultation' 'Therapy']
# treatment_date ['2023-04-22' '2024-02-22' '2022-01-02' '2023-02-10' '2022-09-10'
#  '2023-05-31' '2024-01-20' '2023-01-21' '2022-05-30' '2022-09-24'
#  '2024-05-05' '2022-04-08' '2024-05-25' '2022-10-29' '2023-08-30'
#  '2022-01-21' '2022-01-19' '2024-07-23' '2024-09-21' '2023-11-02'
#  '2024-05-06' '2024-04-26' '2022-04-30' '2023-01-03' '2023-07-07'
#  '2024-05-29' '2024-08-03' '2023-05-22' '2024-07-02' '2024-07-06'
#  '2023-07-24' '2022-11-27' '2023-09-28' '2022-11-30' '2022-07-24'
#  '2022-07-10' '2023-10-10' '2023-06-16' '2023-01-16' '2023-11-03'
#  '2023-10-04' '2023-10-23' '2024-08-27' '2023-09-01' '2024-09-20'
#  '2024-04-24' '2024-01-02' '2024-05-10' '2024-09-18' '2023-07-09'
# ...
